# %%
import numpy as np
import pandas as pd

from Visualization import Plotly_Visualization, Seaborn_Visualization
import plotly.express as px

# %% [markdown]
# # 3D Scatter Plot

# %% [markdown]
#     Experiment_1

# %%
path = "./Data/Experiment_1/"
X_train_dataset, y_train_dataset, X_test_dataset, y_test_dataset = np.load(path + "X_train_dataset.npy"), np.load(path + "y_train_dataset.npy"), np.load(path + "X_test_dataset.npy"), np.load(path + "y_test_dataset.npy")

X = np.concatenate((X_train_dataset[35], X_test_dataset[35]), axis=0)
y = np.concatenate((y_train_dataset[35], y_test_dataset[35]), axis=0)

#vis = Plotly_Visualization(X, y)
#vis.get_3d_1()

vis = Seaborn_Visualization(X,y)
vis.get_3d_1()

# %% [markdown]
#     Experiment_2

# %%
path = "./Data/Experiment_2/"
X_train_dataset_2, y_train_dataset_2, X_test_dataset_2, y_test_dataset_2 = np.load(path + "X_train_dataset.npy"), np.load(path + "y_train_dataset.npy"), np.load(path + "X_test_dataset.npy"), np.load(path + "y_test_dataset.npy")

X2 = np.concatenate((X_train_dataset_2[10], X_test_dataset_2[10]), axis=0)
y2 = np.concatenate((y_train_dataset_2[10], y_test_dataset_2[10]), axis=0)

#vis2 = Plotly_Visualization(X, y)
#vis2.get_3d_1()

vis2 = Seaborn_Visualization(X2,y2)
vis2.get_3d_1()

# %% [markdown]
#     Experiment_3

# %%
path = "./Data/Experiment_3/"
X_train_dataset_3, y_train_dataset_3, X_test_dataset_3, y_test_dataset_3 = np.load(path + "X_train_dataset.npy"), np.load(path + "y_train_dataset.npy"), np.load(path + "X_test_dataset.npy"), np.load(path + "y_test_dataset.npy")

X3 = np.concatenate((X_train_dataset_3[60], X_test_dataset_3[60]), axis=0)
y3 = np.concatenate((y_train_dataset_3[60], y_test_dataset_3[60]), axis=0)

#vis3 = Plotly_Visualization(X, y)
#vis3.get_3d_1()

vis3 = Seaborn_Visualization(X3,y3)
vis3.get_3d_1()

# %% [markdown]
#     Experiment_4

# %%
path = "./Data/Experiment_4/"
X_train_dataset_4, y_train_dataset_4, X_test_dataset_4, y_test_dataset_4 = np.load(path + "X_train_dataset.npy"), np.load(path + "y_train_dataset.npy"), np.load(path + "X_test_dataset.npy"), np.load(path + "y_test_dataset.npy")

X4 = np.concatenate((X_train_dataset_4[80], X_test_dataset_4[80]), axis=0)
y4 = np.concatenate((y_train_dataset_4[80], y_test_dataset_4[80]), axis=0)


#vis4 = Plotly_Visualization(X4, y4)
#vis4.get_3d_1()

vis4 = Seaborn_Visualization(X3,y3)
vis4.get_3d_1()

# %% [markdown]
#     Experiment_5

# %% [markdown]
# -----

# %%
path = "./Data/Experiment_5/"
X_train_dataset_5, y_train_dataset_5, X_test_dataset_5, y_test_dataset_5 = np.load(path + "X_train_dataset.npy"), np.load(path + "y_train_dataset.npy"), np.load(path + "X_test_dataset.npy"), np.load(path + "y_test_dataset.npy")

X5 = np.concatenate((X_train_dataset_5[60], X_test_dataset_5[60]), axis=0)
y5 = np.concatenate((y_train_dataset_5[60], y_test_dataset_5[60]), axis=0)

#vis5 = Plotly_Visualization(X5, y5)
#vis5.get_3d_1()

vis5 = Seaborn_Visualization(X5,y5)
vis5.get_3d_1()
